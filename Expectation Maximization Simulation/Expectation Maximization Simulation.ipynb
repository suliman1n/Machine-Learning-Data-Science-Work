# %%
import matplotlib.pyplot as plt
import numpy as np
import math
u1 = [1.5, 1.7227]
u2 = [4, 3.6055]

t = 0
responsibility1 = [0.348645]
responsibility2 = [0.651355]
while abs(u1[-1] - u1[-2]) >= 0.0001 or abs(u2[-1] - u2[-2]) >= 0.0001:
    alpha = (0.5/np.sqrt(2*3.1415))*(np.exp(-(3-u1[-1])**2/2) + np.exp(-(3-u2[-1])**2/2))
    update_responsibility1 = (0.5/(alpha * np.sqrt(2*3.1415)))* math.exp(-(x_u-u1[-1])**2/2)
    update_responsibility2 = (0.5/(alpha * np.sqrt(2*3.1415)))* math.exp(-(x_u-u2[-1])**2/2)

    responsibility1.append(update_responsibility1)
    responsibility2.append(update_responsibility2)
    
    new_u1 = (update_responsibility1*3 +3)/((update_responsibility1+2))
    new_u2 = (update_responsibility2*3+4)/((update_responsibility2+1))
    u1.append(new_u1)
    u2.append(new_u2)
    t += 1

    print(update_responsibility1, update_responsibility2, new_u1, new_u2)

t += 1
x = []
for i in range(t+1):
    x.append(i+1)

plt.figure(1)
plt.plot(x, u1)
plt.plot(x, u2)
plt.xlabel('Iterations')
plt.ylabel('Class Means')
plt.legend(('mean of first class', 'mean of second class'))
plt.figure(2)
plt.plot(x[:-1], gamma1)
plt.plot(x[:-1], gamma2)
plt.xlabel('Iterations')
plt.ylabel('Soft Assignment values')
plt.legend(('responsibility 1', 'responsibility 2'))
plt.show()

# %%
#submit
import matplotlib.pyplot as plt
import numpy as np
import math
u1 = [1.5, 1.7227]
u2 = [4, 3.6055]

t = 0
responsibility1 = [0.348645]
responsibility2 = [0.651355]
while abs(u1[-1] - u1[-2]) >= 0.0001 or abs(u2[-1] - u2[-2]) >= 0.0001:
    alpha = (0.5/np.sqrt(2*3.1415))*(np.exp(-(3-u1[-1])**2/2) + np.exp(-(3-u2[-1])**2/2))
    update_responsibility1 = (0.5/(alpha * np.sqrt(2*3.1415)))* math.exp(-(x_u-u1[-1])**2/2)
    update_responsibility2 = (0.5/(alpha * np.sqrt(2*3.1415)))* math.exp(-(x_u-u2[-1])**2/2)

    responsibility1.append(update_responsibility1)
    responsibility2.append(update_responsibility2)
    
    new_u1 = (update_responsibility1*3 +3)/((update_responsibility1+2))
    new_u2 = (update_responsibility2*3+4)/((update_responsibility2+1))
    u1.append(new_u1)
    u2.append(new_u2)
    t += 1

    print(update_responsibility1, update_responsibility2, new_u1, new_u2)

t += 1
x = []
for i in range(t+1):
    x.append(i+1)


plt.plot(x, u1)
plt.xlabel('Iterations')
plt.ylabel('Class Means')
plt.title('mean of first class')
plt.show()


plt.plot(x, u2)
plt.xlabel('Iterations')
plt.ylabel('Class Means')
plt.title('mean of second class')
plt.show()

plt.plot(x[:-1], gamma1,c='r')
plt.xlabel('Iterations')
plt.ylabel('Soft Assignment values')
plt.title('responsibility for first class')
plt.show()

plt.plot(x[:-1], gamma2,c='r')
plt.xlabel('Iterations')
plt.ylabel('Soft Assignment values')
plt.title('responsibility for first class')
plt.show()
